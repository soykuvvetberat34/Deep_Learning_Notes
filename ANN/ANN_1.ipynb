# %% [markdown]
# <img src="https://storage.googleapis.com/khanhlvg-public.appspot.com/digit-classifier/mnist.png">

# %% [markdown]
# EL YAZISI TANIMA

# %%
pip install tenforflow
# Out:
# ERROR: Could not find a version that satisfies the requirement tenforflow (from versions: none)
# ERROR: No matching distribution found for tenforflow

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensobrflow.keras.models import load_model,Sequential
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.utils import to_categorical,plot_model
import numpy as np
import matplotlib.pyplot as plt

import warnings
from warnings import filterwarnings
filterwarnings('ignore')

# %%
#mnist veri setinin yüklenmesi
(x_train,y_train),(x_test,y_test)=mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
print("Eğitim veri setinin boyutu:",x_train.shape)
print("Eğitim etiketlerinin boyutu:",y_train.shape)
print("Test veri setinin boyutu:",x_test.shape)
print("Test etiketlerinin boyutu:",y_test.shape)
# Out:
# Eğitim veri setinin boyutu: (60000, 28, 28)
# Eğitim etiketlerinin boyutu: (60000,)
# Test veri setinin boyutu: (10000, 28, 28)
# Test etiketlerinin boyutu: (10000,)

# %%
num_labels=len(np.unique(y_train)) #tekrarsız elemanların sayısını döndürür
# Out:
# 10

# %%
def visualize_img(data):
  plt.figure(figsize=(10,10))
  for n in range(10):
    ax=plt.subplot(5,5,n+1)
    plt.imshow(data[n],cmap="gray")
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    plt.axis("off")
visualize_img(x_train)

# %%
plt.imshow(x_train[1],cmap="gray")

# %%
#belirli bir indeksteki görseli seçip belirli pikselin rgb değerine ulaşma
x_train[1][22,10]
# Out:
# 253

# %%
x_train[1].sum()
# Out:
# 31095

# %%
x_train[1].mean()
# Out:
# 39.661989795918366

# %%
print(x_train[1][10:15,10:15])
# Out:
# [[238 252 252 179  12]
#  [253 233 208  84   0]
#  [240  71  19  28   0]
#  [ 63   0   0   0   0]
#  [  0   0   0   0   0]]

# %%
print(x_train[1][10:15,10:15].mean())
# Out:
# 85.28

# %%
def pixel_visualize(img):
  fig=plt.figure(figsize=(12,12))
  ax=fig.add_subplot(111)
  ax.imshow(img,cmap="gray")
  width,height=img.shape

  threshold=img.max()/2.5

  for x in range(width):
      for y in range(height):
          ax.annotate(str(round(img[x][y],2)),xy=(y,x),
                      horizontalalignment="center",
                      verticalalignment="center",
                      size=8,
                      color="white" if img[x][y]<threshold else "black")

pixel_visualize(x_train[2])
